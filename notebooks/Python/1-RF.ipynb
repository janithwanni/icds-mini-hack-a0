# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
train = pd.read_csv("../../data/train_data.csv")
test = pd.read_csv("../../data/test_data.csv")

# %%
train
# Out:
#           ID      parents     has_nurs        form children     housing  \
# 0          1        usual  less_proper    complete        3    critical
# 1          2  pretentious    very_crit   completed        1  convenient
# 2          3  pretentious       proper  incomplete        1   less_conv
# 3          4   great_pret     improper    complete        1  convenient
# 4          5   great_pret  less_proper   completed        1  convenient
# ...      ...          ...          ...         ...      ...         ...
# 10363  10364        usual     improper  incomplete        3   less_conv
# 10364  10365   great_pret  less_proper  incomplete        3  convenient
# 10365  10366  pretentious       proper    complete        2   less_conv
# 10366  10367  pretentious    very_crit   completed        1   less_conv
# 10367  10368   great_pret     critical    complete        3   less_conv
#
#           finance         social       health  app_status
# 0      convenient    problematic    not_recom           0
# 1          inconv        nonprob    not_recom           0
# 2      convenient  slightly_prob     priority           1
# 3      convenient        nonprob  recommended           1
# 4      convenient  slightly_prob     priority           1
# ...           ...            ...          ...         ...
# 10363  convenient    problematic  recommended           1
# 10364      inconv        nonprob    not_recom           0
# 10365      inconv    problematic     priority           1
# 10366  convenient  slightly_prob    not_recom           0
# 10367  convenient  slightly_prob  recommended           0
#
# [10368 rows x 10 columns]

# %%
train.columns
# Out:
# Index(['ID', 'parents', 'has_nurs', 'form', 'children', 'housing', 'finance',
#        'social', 'health', 'app_status'],
#       dtype='object')

# %%
def preprocess(df,train=False):
    df.loc[df.form == "completed","form"] = "complete"
    str_cols = ['parents', 'has_nurs', 'form', 'children', 'housing', 'finance','social', 'health']
    result = pd.concat([pd.DataFrame({"ID":df.ID.values.tolist()}),
           pd.get_dummies(df.loc[:,str_cols])],axis=1)
    result = result if not train else pd.concat([result,
                                         pd.DataFrame({"app_status":df.app_status.values.tolist()})],axis=1)
    return result

# %%
ptrain = preprocess(train,train=True)
ptest = preprocess(test,train=False)

# %%
train.loc[train.form == "completed","form"] = "complete"

# %%
pd.concat([pd.DataFrame({"ID":train.ID.values.tolist()}),
           pd.get_dummies(train.loc[:,str_cols]),
           pd.DataFrame({"app_status":train.app_status.values.tolist()})],axis=1)
# Out:
#           ID  parents_great_pret  parents_pretentious  parents_usual  \
# 0          1                   0                    0              1
# 1          2                   0                    1              0
# 2          3                   0                    1              0
# 3          4                   1                    0              0
# 4          5                   1                    0              0
# ...      ...                 ...                  ...            ...
# 10363  10364                   0                    0              1
# 10364  10365                   1                    0              0
# 10365  10366                   0                    1              0
# 10366  10367                   0                    1              0
# 10367  10368                   1                    0              0
#
#        has_nurs_critical  has_nurs_improper  has_nurs_less_proper  \
# 0                      0                  0                     1
# 1                      0                  0                     0
# 2                      0                  0                     0
# 3                      0                  1                     0
# 4                      0                  0                     1
# ...                  ...                ...                   ...
# 10363                  0                  1                     0
# 10364                  0                  0                     1
# 10365                  0                  0                     0
# 10366                  0                  0                     0
# 10367                  1                  0                     0
#
#        has_nurs_proper  has_nurs_very_crit  form_complete  ...  \
# 0                    0                   0              1  ...
# 1                    0                   1              1  ...
# 2                    1                   0              0  ...
# 3                    0                   0              1  ...
# 4                    0                   0              1  ...
# ...                ...                 ...            ...  ...
# 10363                0                   0              0  ...
# 10364                0                   0              0  ...
# 10365                1                   0              1  ...
# 10366                0                   1              1  ...
# 10367                0                   0              1  ...
#
#        housing_less_conv  finance_convenient  finance_inconv  social_nonprob  \
# 0                      0                   1               0               0
# 1                      0                   0               1               1
# 2                      1                   1               0               0
# 3                      0                   1               0               1
# 4                      0                   1               0               0
# ...                  ...                 ...             ...             ...
# 10363                  1                   1               0               0
# 10364                  0                   0               1               1
# 10365                  1                   0               1               0
# 10366                  1                   1               0               0
# 10367                  1                   1               0               0
#
#        social_problematic  social_slightly_prob  health_not_recom  \
# 0                       1                     0                 1
# 1                       0                     0                 1
# 2                       0                     1                 0
# 3                       0                     0                 0
# 4                       0                     1                 0
# ...                   ...                   ...               ...
# 10363                   1                     0                 0
# 10364                   0                     0                 1
# 10365                   1                     0                 0
# 10366                   0                     1                 1
# 10367                   0                     1                 0
#
#        health_priority  health_recommended  app_status
# 0                    0                   0           0
# 1                    0                   0           0
# 2                    1                   0           1
# 3                    0                   1           1
# 4                    1                   0           1
# ...                ...                 ...         ...
# 10363                0                   1           1
# 10364                0                   0           0
# 10365                1                   0           1
# 10366                0                   0           0
# 10367                0                   1           0
#
# [10368 rows x 28 columns]

# %%
X = ptrain.drop(["app_status","ID"],axis=1)
y = ptrain.app_status
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,train_size=0.65,test_size=0.35)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((6739, 26), (3629, 26), (6739,), (3629,))

# %%
rf = RandomForestClassifier().fit(X_train,y_train)

# %%
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2311
#            1       0.99      0.98      0.98      1318
#
#     accuracy                           0.99      3629
#    macro avg       0.99      0.98      0.99      3629
# weighted avg       0.99      0.99      0.99      3629

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test,y_pred)
auc(fpr,tpr)
# Out:
# 0.9847780523182326

# %%
for i,v in enumerate(rf.feature_importances_):
    print(f"Feature {X.columns[i]} importance {v}")
# Out:
# Feature parents_great_pret importance 0.06191131524795117
# Feature parents_pretentious importance 0.02320848661529852
# Feature parents_usual importance 0.04365425215775274
# Feature has_nurs_critical importance 0.05176963458324169
# Feature has_nurs_improper importance 0.02997243854164249
# Feature has_nurs_less_proper importance 0.05211561664591287
# Feature has_nurs_proper importance 0.05733959383060021
# Feature has_nurs_very_crit importance 0.09140989523664853
# Feature form_complete importance 0.014010414513133798
# Feature form_foster importance 0.01192704513181296
# Feature form_incomplete importance 0.007581913506217928
# Feature children_1 importance 0.020578615449988832
# Feature children_2 importance 0.011613553006665405
# Feature children_3 importance 0.011624089820462718
# Feature children_more importance 0.011675141520424055
# Feature housing_convenient importance 0.022180242875515427
# Feature housing_critical importance 0.017942042120596868
# Feature housing_less_conv importance 0.01037050261784327
# Feature finance_convenient importance 0.012741168037890523
# Feature finance_inconv importance 0.014083105121954296
# Feature social_nonprob importance 0.010981000770084973
# Feature social_problematic importance 0.0313790445571931
# Feature social_slightly_prob importance 0.011244223857642937
# Feature health_not_recom importance 0.20605604103444589
# Feature health_priority importance 0.05115733442366162
# Feature health_recommended importance 0.1114732887754172

# %%
tX = ptest.drop(["ID"],axis=1)
tpred = rf.predict(tX)

# %%
tpred
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
sample_sub = pd.read_csv("../../data/sampleSubmissionFile.csv")
sample_sub["app_status"] = tpred
sample_sub
# Out:
#         ID  app_status
# 0        1           1
# 1        2           1
# 2        3           1
# 3        4           1
# 4        5           1
# ...    ...         ...
# 2587  2588           0
# 2588  2589           0
# 2589  2590           0
# 2590  2591           0
# 2591  2592           0
#
# [2592 rows x 2 columns]

# %%
from datetime import datetime
sample_sub.to_csv(f"rf-attempt-{datetime.now()}.csv",index=False)
